# %%
pip install ollama
# Out:
# Requirement already satisfied: ollama in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (0.4.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ollama) (2.10.2)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ollama) (0.27.0)
# Requirement already satisfied: sniffio in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.3.1)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2.10)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.2.2)
# Requirement already satisfied: anyio in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (4.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.12.2)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.27.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load input file

# %%
import os

project_title_map = {
        "archives_space": "Archives Space Project",
        "neurohub": "NeuroHub Project",
        "open_spending": "Open Spending Project",
        "planning_poker": "Planning Poker Project",
        "recycling": "Recycling Project",
        "color_ide": "ColorIDE Project"
    }
projects = ["archives_space", "neurohub", "open_spending", "planning_poker", "recycling", "color_ide"]

#selected_project = os.environ.get("project")
#file_copy_index = os.environ.get("input_file_copy_index")
selected_project = projects[2]
file_name = "user_stories_{}.json".format(selected_project)
project_path = "./input_files/{}".format(file_name)
with open(project_path, 'r') as file:
        project_content = file.read()
        project_title = project_title_map[selected_project]

# %% [markdown]
# # Configure model parameters

# %%
import ollama
from ollama import Client

#model_version = "llama3.1:8b-instruct-fp16"
model_version = "llama3.1:70b"
num_ctx = 20480 # context length is higher because of the refinement process
temperature = 0 # should be kept 0 for deterministic results, default value 0.8

options = {"num_ctx": num_ctx, "temperature": temperature}
model_name = model_version

one_shot = False

# %% [markdown]
# # Get analysis messages for each pattern

# %%
client = Client(
  headers={}
)
analysis_list = []
import time

patterns = ["Layered Architecture",
    "Event-Driven Architecture",
    "Microkernel Architecture",
    "Microservices Architecture",
    "Space-Based Architecture",
    "Pipeline Architecture",
    "Client-Server Architecture"]

analyzer_system_message = {'role': 'system', 'content': f"""
You are an expert software architect. Your task is to provide a comprehensive analysis of the suitability of a given architectural pattern for a software project described by user stories.
Consider various aspects, such as scalability, complexity, performance, maintainability, accessibility and any other factors you deem relevant to making a thorough assessment.
Provide a detailed reasoning for each aspect, referencing the relevant user stories.
Think step by step and explain your though process clearly.
After your analysis give a score for the suitability on this scale:

1: "Completely unsuitable"
2: "Partially suitable"
3: "Moderately applicable"
4: "Well suited"
5: "Perfectly aligned"

Here is the format for an example run:

PROJECT TITLE: <title>

CATEGORIZED USER STORIES:

<user stories>

ARCHITECTURE PATTERN: <pattern>

ANALYSIS:

<analysis>

SCORE: <int>
"""}


start_time = time.time()
for pattern in patterns:
  analyzer_context = []
  analyzer_context.append(analyzer_system_message)
  analyzer_context.append({'role': 'user', 'content': f"""
  I will give you a list of categorized user stories and a description created for a software project titled {project_title}. 
  Analyze the following user stories and assess the suitability of the {pattern} architecture for this project.
  PROJECT TITLE: {project_title}

  CATEGORIZED USER STORIES:

  {project_content}

  ARCHITECTURE PATTERN: {pattern}

  ANALYSIS:
  
  """})
  response = client.chat(model=model_name, messages=analyzer_context, options=options)
  

  message = response['message']
  print(message['content'].strip())
  analysis_list.append(message['content'].strip())
end_time = time.time()
analysis_duration = end_time - start_time
# Out:
# ANALYSIS:
#
# The Open Spending Project is a complex system that requires a robust architecture to support its various features and user stories. The Layered Architecture pattern is a suitable choice for this project, as it provides a clear separation of concerns and allows for scalability, maintainability, and flexibility.
#
# **Scalability:**
# The layered architecture allows for horizontal scaling, where each layer can be scaled independently without affecting the other layers. This is particularly important for the Open Spending Project, which requires handling large datasets and high traffic volumes (User Story: "As an API User, I want a consistent download/upload speed even at moments when the website has a lot of user traffic."). The layered architecture enables the system to scale efficiently and maintain performance under heavy loads.
#
# **Complexity:**
# The Open Spending Project involves multiple features and functionalities, such as data ingestion, processing, visualization, and sharing. The layered architecture helps to manage this complexity by breaking down the system into smaller, more manageable components. Each layer has a specific responsibility, making it easier to develop, test, and maintain.
#
# **Performance:**
# The layered architecture allows for optimization of each layer independently, which can improve overall system performance. For example, the data ingestion layer can be optimized for high-speed data processing, while the visualization layer can be optimized for fast rendering (User Story: "As a Data Consuming User, I want to be able to download a CSV of the data that is used in any visualisation I am viewing").
#
# **Maintainability:**
# The layered architecture makes it easier to maintain and update individual components without affecting the entire system. This is particularly important for the Open Spending Project, which requires frequent updates and changes to its features and functionalities (User Story: "As a Data Publishing User, I want to be able to edit a dataset I have published").
#
# **Accessibility:**
# The layered architecture provides a clear separation of concerns, making it easier to implement accessibility features. For example, the visualization layer can be designed with accessibility in mind, without affecting the other layers.
#
# **Other factors:**
#
# * **Modularity:** The layered architecture promotes modularity, which is essential for the Open Spending Project's extensibility and flexibility requirements (User Story: "As a Developer, I want to design the system using distributed, decoupled patterns that promote loose coupling").
# * **Flexibility:** The layered architecture allows for changes in individual layers without affecting the entire system, making it easier to adapt to changing requirements.
# * **Implementability:** The layered architecture provides a clear structure and separation of concerns, making it easier to implement new features and functionalities.
#
# **SCORE:**
# Based on the analysis above, I would score the suitability of the Layered Architecture pattern for the Open Spending Project as:
#
# 4: "Well suited"
#
# The layered architecture provides a robust foundation for the Open Spending Project's complex requirements. While there may be some challenges in implementing this architecture, its benefits in terms of scalability, maintainability, and flexibility make it an excellent choice for this project.
# ANALYSIS:
#
# The Open Spending Project is a complex system that involves data ingestion, processing, visualization, and sharing. The Event-Driven Architecture (EDA) pattern is being considered for this project. Here's an analysis of the suitability of EDA for this project based on various aspects.
#
# **Scalability:**
# EDA is well suited for large-scale systems like Open Spending Project. It allows for horizontal scaling by adding more nodes to handle increased traffic or data volume. The system can process events in parallel, making it highly scalable. (Score: 5)
#
# **Complexity:**
# The EDA pattern introduces additional complexity due to the need to manage event producers, consumers, and brokers. However, this complexity is manageable with proper design and implementation. The benefits of scalability and flexibility outweigh the added complexity. (Score: 4)
#
# **Performance:**
# EDA can provide high performance by allowing events to be processed in parallel. This enables the system to handle large volumes of data and traffic without significant degradation in performance. (Score: 5)
#
# **Maintainability:**
# The EDA pattern promotes loose coupling between components, making it easier to maintain and update individual components without affecting the entire system. However, the added complexity of event management may require additional maintenance efforts. (Score: 4)
#
# **Accessibility:**
# EDA does not inherently provide accessibility features. However, the system can be designed to provide accessible APIs and interfaces for users with disabilities. (Score: 3)
#
# **Integrability & Interoperability:**
# The EDA pattern enables easy integration with other systems by providing a standardized event-based interface. This facilitates interoperability between different components and systems. (Score: 5)
#
# **Security & Confidentiality:**
# EDA does not inherently provide security features. However, the system can be designed to implement robust security measures, such as encryption and access control, to protect sensitive data. (Score: 3)
#
# **Manageability & Maintainability:**
# The EDA pattern provides a high degree of manageability by allowing administrators to monitor and control event flows. This enables efficient management of the system and its components. (Score: 5)
#
# **Modularity & Extensibility:**
# EDA promotes modularity by enabling individual components to be developed, tested, and deployed independently. This facilitates extensibility by allowing new components to be added or existing ones to be modified without affecting the entire system. (Score: 5)
#
# **Performance Efficiency & Resource Utilization:**
# The EDA pattern can provide high performance efficiency by optimizing resource utilization through parallel processing of events. (Score: 5)
#
# **Variability & Flexibility:**
# EDA provides a high degree of variability and flexibility by enabling different event producers, consumers, and brokers to be added or modified without affecting the entire system. (Score: 5)
#
# **Implementability & Ease of Development:**
# The EDA pattern can provide ease of development by allowing developers to focus on individual components rather than the entire system. However, the added complexity of event management may require additional development efforts. (Score: 4)
#
# **Exchangeability & Replaceability:**
# EDA provides a high degree of exchangeability and replaceability by enabling different components to be swapped out or replaced without affecting the entire system. (Score: 5)
#
# **Analyzability & Traceability:**
# The EDA pattern can provide analyzability and traceability features by enabling event flows to be monitored and analyzed. This facilitates debugging and troubleshooting of issues within the system. (Score: 5)
#
# SCORE: 4.6
#
# Based on this analysis, the Event-Driven Architecture pattern is well suited for the Open Spending Project. It provides scalability, performance, maintainability, and flexibility, which are essential for a complex system like Open Spending Project. However, it introduces additional complexity due to event management, which requires careful design and implementation.
# PROJECT TITLE: Open Spending Project
#
# CATEGORIZED USER STORIES:
#
# ... (as provided)
#
# ARCHITECTURE PATTERN: Microkernel Architecture
#
# ANALYSIS:
#
# The Microkernel Architecture pattern is a suitable choice for the Open Spending Project, considering its requirements and user stories. Here's a detailed analysis of various aspects:
#
# **Scalability**: The Microkernel Architecture allows for horizontal scaling, which aligns with the project's need to handle large datasets and high traffic (e.g., "As an API User, I want queries to be processed using a distributed processing approach..."). This architecture enables the addition of new nodes as needed, ensuring that the system can scale to meet increasing demands. (Score: 4)
#
# **Complexity**: The Microkernel Architecture is relatively simple and easy to understand, which is beneficial for a project with diverse user roles and requirements. However, it may introduce additional complexity when dealing with distributed processing and node communication. (Score: 3)
#
# **Performance**: By decoupling data ingestion from processing, the Microkernel Architecture enables efficient handling of large datasets and high traffic. This aligns with several user stories, such as "As an API User, I want queries to be processed using a distributed processing approach..." and "As a Data Consuming User, I want data visualizations to be served from a dynamic, in-memory data store...". (Score: 4)
#
# **Maintainability**: The Microkernel Architecture promotes loose coupling between components, making it easier to maintain and update individual modules without affecting the entire system. This aligns with user stories like "As a Developer, I want to design the system using distributed, decoupled patterns..." and "As a Platform Administrator, I want to deploy and monitor distributed processing nodes...". (Score: 4)
#
# **Accessibility**: The Microkernel Architecture does not inherently impact accessibility. However, by providing a flexible and scalable architecture, it enables the development of accessible features, such as customizable branding and styling (e.g., "As an API user, I want to be able to change some of the styling of the embedded Viewer..."). (Score: 3)
#
# **Implementability & Ease of Development**: The Microkernel Architecture is relatively easy to implement, especially when compared to more complex architectures. However, it may require additional effort to set up and manage distributed processing nodes. (Score: 3)
#
# **Variability & Flexibility**: The Microkernel Architecture provides a flexible foundation for the project, allowing for various customization options, such as changing colors and styling of embedded visualizations (e.g., "As an API user, I want to be able to change some of the styling of the embedded Viewer..."). (Score: 4)
#
# **Exchangeability & Replaceability**: The Microkernel Architecture does not inherently impact exchangeability or replaceability. However, its modular design makes it easier to swap out individual components if needed. (Score: 3)
#
# **Analyzability & Traceability**: The Microkernel Architecture provides a clear and understandable structure, making it easier to analyze and debug issues. (Score: 4)
#
# SCORE: 3.8
#
# The Microkernel Architecture is well suited for the Open Spending Project, considering its requirements and user stories. While there are some areas where the architecture may introduce additional complexity or require more effort to implement, its benefits in terms of scalability, performance, maintainability, and flexibility make it a suitable choice for this project.
# ANALYSIS:
#
# The Open Spending Project is a complex system that requires handling large amounts of data, providing various visualization options, and ensuring scalability, performance, and maintainability. After analyzing the user stories, I will assess the suitability of the Microservices Architecture pattern for this project.
#
# **Scalability:**
# Microservices Architecture is well suited for scalable systems, as it allows for individual services to be scaled independently. This aligns with several user stories, such as "As a Data Consuming User, I want to be able to download a CSV of the data that is used in any visualisation I am viewing" and "As an API User, I want queries to be processed using a distributed processing approach". Score: 5
#
# **Complexity:**
# The Microservices Architecture pattern can help manage complexity by breaking down the system into smaller, independent services. However, it also introduces additional complexity due to the need for service discovery, communication, and coordination. This might make it more challenging to implement some user stories, such as "As a Data Publishing User, I want to be able to edit the model of data I have already imported". Score: 3
#
# **Performance:**
# Microservices Architecture can improve performance by allowing services to be optimized independently. However, it also introduces additional overhead due to inter-service communication. This might impact the performance of some user stories, such as "As a Data Consuming User, I want data visualizations to be served from a dynamic, in-memory data store". Score: 4
#
# **Maintainability:**
# The Microservices Architecture pattern can improve maintainability by allowing services to be updated and deployed independently. This aligns with several user stories, such as "As a Data Publishing User, I want to be able to edit the model of data I have already imported" and "As a Platform Administrator, I want to deploy and monitor distributed processing nodes". Score: 5
#
# **Accessibility:**
# Microservices Architecture does not directly impact accessibility. However, it can provide more flexibility in terms of service deployment and scaling, which might improve overall system responsiveness and usability. Score: 4
#
# **Other factors:**
#
# * **Modularity & Extensibility:** Microservices Architecture is well suited for modular and extensible systems, as it allows new services to be added or removed independently. This aligns with several user stories, such as "As a Data Publishing User, I want to be able to edit the model of data I have already imported" and "As a Developer, I want to design the system using distributed, decoupled patterns that promote loose coupling". Score: 5
# * **Implementability & Ease of Development:** Microservices Architecture can make implementation more complex due to the need for service discovery, communication, and coordination. However, it also provides more flexibility in terms of technology choices and deployment options. Score: 3
#
# **Overall score:** 4.1
#
# The Microservices Architecture pattern is well suited for the Open Spending Project, as it provides scalability, maintainability, and modularity benefits that align with many user stories. However, it also introduces additional complexity and overhead due to inter-service communication and coordination. With careful planning and implementation, the Microservices Architecture pattern can help achieve the project's goals.
#
# SCORE: 4
# PROJECT TITLE: Open Spending Project
#
# CATEGORIZED USER STORIES:
#
# ... (as provided)
#
# ARCHITECTURE PATTERN: Space-Based Architecture
#
# ANALYSIS:
#
# The Space-Based Architecture pattern is a distributed architecture that separates the application logic into three main components: Data, Processing, and Presentation. This separation allows for scalability, flexibility, and maintainability.
#
# **Scalability:** The user stories related to handling large datasets, high traffic, and concurrent requests (e.g., "As an API User, I want queries to be processed using a distributed processing approach...") suggest that the system needs to scale horizontally. Space-Based Architecture's separation of concerns allows for easy addition of new nodes to handle increased load, making it well suited for scalability.
#
# **Complexity:** The user stories related to data ingestion, processing, and visualization (e.g., "As a Data Publishing User, I want to be able to import data in Excel...") suggest that the system needs to handle complex data flows. Space-Based Architecture's separation of concerns helps to manage this complexity by breaking down the application logic into smaller, more manageable components.
#
# **Performance:** The user stories related to real-time updates and traffic spikes (e.g., "As a Data Consuming User, I want data visualizations to be served from a dynamic, in-memory data store...") suggest that the system needs to perform well under high loads. Space-Based Architecture's use of distributed processing and caching can help improve performance.
#
# **Maintainability:** The user stories related to customizability and branding (e.g., "As an API user, I want to be able to change some of the styling of the embedded Viewer...") suggest that the system needs to be maintainable. Space-Based Architecture's separation of concerns makes it easier to modify or replace individual components without affecting the entire system.
#
# **Accessibility:** The user stories related to accessibility (e.g., "As a Data Consuming User, I want to see textual descriptions that accompany embedded visualisations...") suggest that the system needs to be accessible. Space-Based Architecture's separation of concerns can help ensure that accessibility features are implemented consistently across the application.
#
# **Other factors:**
#
# * **Security:** The user stories related to security (e.g., "As a Data Publishing User, I want to be able to add a dataset in a Hidden state...") suggest that the system needs to implement proper access controls. Space-Based Architecture's separation of concerns can help ensure that security features are implemented consistently across the application.
# * **Integrability:** The user stories related to integrations with other systems (e.g., "As an API User, I want to be able to get bordering regions|cities when I query a region|city...") suggest that the system needs to integrate with external systems. Space-Based Architecture's use of APIs and messaging can help facilitate these integrations.
#
# SCORE: 4
#
# The Space-Based Architecture pattern is well suited for the Open Spending Project, as it addresses many of the scalability, complexity, performance, maintainability, accessibility, security, and integrability concerns raised by the user stories. However, a score of 5 would require an even more perfect alignment between the architecture pattern and the project requirements, which may not be possible given the complexity of the project.
# ANALYSIS:
#
# The Open Spending Project is a complex system that involves data ingestion, processing, visualization, and sharing. The user stories highlight the need for scalability, performance, maintainability, accessibility, and flexibility.
#
# Pipeline Architecture is a suitable pattern for this project as it allows for the decomposition of the system into smaller, independent components that can be developed, tested, and deployed separately. This architecture also enables parallel processing, which can improve performance and scalability.
#
# Here's a detailed analysis of each aspect:
#
# 1. **Scalability**: Pipeline Architecture supports horizontal scaling, which means that new nodes can be added to the pipeline as needed to handle increased traffic or data volume. This aligns with user stories such as "As an API User, I want queries to be processed using a distributed processing approach..." and "As a Data Publishing User, I want the data import pipeline to be implemented in a highly scalable and distributed manner...".
#
# 2. **Complexity**: The Pipeline Architecture can handle complex data flows and processing requirements, which is evident from user stories such as "As a Data Consuming User, I want to be able to filter, sort and aggregate data by multiple dimensions and measures..." and "As an API User, I want to be able to get bordering regions|cities when I query a region|city...".
#
# 3. **Performance**: The parallel processing capabilities of Pipeline Architecture can improve performance, which is critical for user stories such as "As a Data Consuming User, I want data visualizations to be served from a dynamic, in-memory data store..." and "As an API User, I want consistently fast API access even for the larger datasets...".
#
# 4. **Maintainability**: The modular nature of Pipeline Architecture makes it easier to maintain and update individual components without affecting the entire system, which aligns with user stories such as "As a Data Publishing User, I want to be able to edit the model of data I have already imported..." and "As a Developer, I want to design the system using distributed, decoupled patterns...".
#
# 5. **Accessibility**: The Pipeline Architecture can support multiple interfaces and APIs, making it accessible to different types of users, which is evident from user stories such as "As a Data Consuming User, I want to be able to share an image of a particular view state to the social networks..." and "As an API User, I want to be able to change the colors of the embedded visualisations...".
#
# 6. **Flexibility**: The Pipeline Architecture can accommodate changing requirements and new features, which is critical for user stories such as "As a Developer, I want to integrate distributed in-memory data grids for caching and state management..." and "As a Platform Administrator, I want to deploy and monitor distributed processing nodes...".
#
# SCORE: 4
#
# The Pipeline Architecture pattern is well suited for the Open Spending Project, as it supports scalability, performance, maintainability, accessibility, and flexibility. However, there may be some challenges in implementing this architecture, such as managing complex data flows and ensuring consistency across different components.
# PROJECT TITLE: Open Spending Project
#
# CATEGORIZED USER STORIES:
#
# ... (as provided)
#
# ARCHITECTURE PATTERN: Client-Server Architecture
#
# ANALYSIS:
#
# The Client-Server Architecture pattern is a widely used architectural style that separates the application logic into two main components: the client and the server. In this analysis, we will assess the suitability of this architecture for the Open Spending Project.
#
# **Scalability (Score: 4/5)**
#
# The Client-Server Architecture can scale horizontally by adding more servers to handle increased traffic. However, it may require additional infrastructure and configuration to manage the load balancing and ensure seamless communication between clients and servers. The user stories related to performance efficiency and resource utilization (e.g., "As an API User, I want queries to be processed using a distributed processing approach...") suggest that scalability is crucial for this project.
#
# **Complexity (Score: 3/5)**
#
# The Client-Server Architecture can become complex when dealing with multiple clients, servers, and data sources. The user stories related to integrability and interoperability (e.g., "As a Data Publishing User, I want to be able to import data in Excel...") indicate that the system needs to handle various data formats and sources, which may add complexity.
#
# **Performance (Score: 4/5)**
#
# The Client-Server Architecture can provide good performance if designed correctly. The user stories related to performance efficiency and resource utilization suggest that the system should be able to handle large datasets and high traffic without compromising response times.
#
# **Maintainability (Score: 3/5)**
#
# The Client-Server Architecture can make maintenance more challenging due to the separation of concerns between clients and servers. However, this also allows for independent updates and bug fixes on either side without affecting the other. The user stories related to manageability and maintainability (e.g., "As a Data Publishing User, I want to be able to edit a dataset I have published...") suggest that maintenance is important for this project.
#
# **Accessibility (Score: 4/5)**
#
# The Client-Server Architecture can provide good accessibility if designed with accessibility in mind. The user stories related to usability and accessibility (e.g., "As a Data Consuming User, I want to be able to filter, sort and aggregate data...") suggest that the system should be accessible to users with varying abilities.
#
# **Other factors**
#
# * **Security**: The Client-Server Architecture can provide good security if designed correctly. However, it also introduces additional attack surfaces (e.g., client-side vulnerabilities). The user stories related to security and confidentiality (e.g., "As a Data Publishing User, I want to be able to add a dataset in a Hidden state...") suggest that security is important for this project.
# * **Modularity**: The Client-Server Architecture can provide good modularity if designed correctly. However, it may require additional effort to ensure loose coupling between clients and servers. The user stories related to modularity and extensibility (e.g., "As a Developer, I want to design the system using distributed, decoupled patterns...") suggest that modularity is important for this project.
#
# SCORE: 3.5/5
#
# The Client-Server Architecture pattern is partially suitable for the Open Spending Project. While it provides good scalability, performance, and accessibility, it may introduce complexity and require additional effort to ensure maintainability, security, and modularity. A more detailed analysis of the specific requirements and constraints of the project would be necessary to determine the final suitability of this architecture.

# %%
analysis_messages_merged =" - DETAILED ANALYSIS MESSAGES FOR EACH PATTERN -"


for pattern, analysis in zip(patterns, analysis_list):
    analysis_messages_merged = analysis_messages_merged + "\n\n Analysis for {}:\n".format(pattern) + analysis

decider_context = []
decider_system_message = {'role': 'system', 'content': f"""
You are a software architect. You will get a list of categorized user stories with a description and a list of analyses that are related to the suitability of each architecture pattern.
Your job is to re-evaluate the user stories and the given analyses together and come up with a final scoring for the architecture patterns. 
- Be as objective as possible during your reasoning. The analysis needs to be deterministic and reproducible, regardless of the order of elements presented or any random factors.
-Explain your thought process clearly.

Here are the score options and their corresponding meaning, your scores must be an integer from 1 to 5 matching these values:
1: "Completely unsuitable"
2: "Partially suitable"
3: "Moderately applicable"
4: "Well suited"
5: "Perfectly aligned"

The final scores must be given in json format after the detailed reasoning for each architecture pattern:
{{
  "Layered Architecture": <int>,
  "Event-Driven Architecture": <int>,
  "Microkernel Architecture": <int>,
  "Microservices Architecture":<int>,
  "Space-Based Architecture": <int>,
  "Pipeline Architecture": <int>,
  "Client-Server Architecture": <int>
}}


Here would be the format for an example run:

PROJECT TITLE: <title>

CATEGORIZED USER STORIES:

<user stories>

- DETAILED ANALYSIS MESSAGES FOR EACH PATTERN -

<list of analyses>

REASONING:

<reasoning>

FINAL SCORE FORMAT:

{{
  "Layered Architecture": <int>,
  "Event-Driven Architecture": <int>,
  "Microkernel Architecture": <int>,
  "Microservices Architecture":<int>,
  "Space-Based Architecture": <int>,
  "Pipeline Architecture": <int>,
  "Client-Server Architecture": <int>
}}
"""}

decider_context.append(decider_system_message)

decider_user_message = {'role': 'user', 'content': f"""
I will give you a list of categorized user stories and a description created for a software project titled {project_title}.
And then I will give you a list of analyses that are related to the mentioned software architecture patterns.
Please re-evaluate them thoroughly and give me a final scoring in json format.

PROJECT TITLE: {project_title}

CATEGORIZED USER STORIES:

{project_content}

{analysis_messages_merged}

REASONING:

"""}

decider_context.append(decider_user_message)
response = client.chat(model=model_name, messages=decider_context, options=options)
  

message = response['message']
print(message['content'].strip())
decider_context.append(message)
end_time = time.time()
decision_duration = end_time - start_time
# Out:
# Based on the provided user stories and analyses for each architecture pattern, I will provide a final scoring in JSON format.
#
#
# {
#   "Layered Architecture": 4,
#   "Event-Driven Architecture": 4.6,
#   "Microkernel Architecture": 3.8,
#   "Microservices Architecture": 4.1,
#   "Space-Based Architecture": 4,
#   "Pipeline Architecture": 4,
#   "Client-Server Architecture": 3.5
# }
#
# Note that the scores are based on a subjective analysis of the suitability of each architecture pattern for the Open Spending Project, considering various aspects such as scalability, complexity, performance, maintainability, accessibility, and flexibility.

# %%
import json

def parse_json_in_string(s):
    """
    Parses and returns the first JSON object found in the input string.

    Args:
        s (str): The input string that contains at least one JSON object.

    Returns:
        object: The Python representation of the parsed JSON object.

    Raises:
        ValueError: If no JSON object is found or if decoding fails.
    """
    # Find the first occurrence of '{'
    start = s.find('{')
    if start == -1:
         return None

    decoder = json.JSONDecoder()
    try:
        obj, _ = decoder.raw_decode(s, idx=start)
        return obj
    except json.JSONDecodeError as e:
        return None

# %% [markdown]
# # Print log to output file

# %%
from datetime import datetime
import json
from pathlib import Path
Path("./logs/separate-analyzer-zero-shot").mkdir(parents=True, exist_ok=True)

final_data = {
        "modelName": model_name,
        "temperature": temperature,
        "context_limit": num_ctx,
        "projectTitle": project_title,
        "file_name": file_name,
        "selfRefinement": False,
        "oneShot": one_shot,
        "timestamp": datetime.now().strftime("%Y%m%d_%H%M%S"),
        "json_output_parsed": parse_json_in_string(decider_context[-1]["content"]),
        "lastMessage": decider_context[-1]["content"],
        "numberOfIterations": 0,
        "maxIterationsAllowed": 0,
        "messages": [message["content"] for message in decider_context],
        "overallDuration": decision_duration,
        "analysisDuration": analysis_duration
    }
    
# 3) Generate a filename based on model name and current timestamp
if one_shot:
    filename = f"./logs/separate-analyzer-one-shot/log_{model_version}_{final_data['timestamp']}.json"
else:
    filename = f"./logs/separate-analyzer-zero-shot/log_{model_version}_{final_data['timestamp']}.json"
# 4) Write the conversation to a JSON file
with open(filename, "w", encoding="utf-8") as f:
    json.dump(final_data, f, indent=2, ensure_ascii=False)

print(f"Assesment complete. The whole conversation is saved to {filename}")
# Out:
# Assesment complete. The whole conversation is saved to ./logs/separate-analyzer-zero-shot/log_llama3.1:70b_20250203_025031.json
